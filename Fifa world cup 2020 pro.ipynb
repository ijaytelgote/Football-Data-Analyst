# %%
'''Fifa world cup 2020'''
import pandas as pd

import numpy as np

from matplotlib import pyplot as plt

import seaborn as sb

# %%
player20=pd.read_csv(r'C:\Users\jayma\Downloads\0player.csv')

# %%
player20.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age        dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  6/24/1987
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34   2/5/1985
# 2          Neymar Jr        Neymar da Silva Santos Junior   27   2/5/1992
# 3           J. Oblak                            Jan Oblak   26   1/7/1993
# 4          E. Hazard                          Eden Hazard   28   1/7/1991
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
for col in player20.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
ply=player20

# %%
ply.shape
# Out:
# (18278, 104)

# %%
ply['nationality']
# Out:
# 0        Argentina
# 1         Portugal
# 2           Brazil
# 3         Slovenia
# 4          Belgium
#            ...
# 18273     China PR
# 18274     China PR
# 18275     China PR
# 18276     China PR
# 18277     China PR
# Name: nationality, Length: 18278, dtype: object

# %%
ply['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
ply['nationality'].value_counts().head(70)
# Out:
# England       1667
# Germany       1216
# Spain         1035
# France         984
# Argentina      886
#               ...
# Montenegro      33
# Egypt           30
# Costa Rica      30
# Jamaica         29
# Georgia         25
# Name: nationality, Length: 70, dtype: int64

# %%
ply
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
#FOR PLOTTING THE GRAPH
plt.figure(figsize=(5,2))
plt.bar(list(ply['age'].value_counts()[:125].keys()),ply['age'].value_counts()[:125],color='grey')
plt.plot()
# Out:
# C:\Users\jayma\AppData\Local\Temp\ipykernel_35344\26243375.py:3: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.bar(list(ply['age'].value_counts()[:125].keys()),ply['age'].value_counts()[:125],color='grey')
# C:\Users\jayma\AppData\Local\Temp\ipykernel_35344\26243375.py:3: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.bar(list(ply['age'].value_counts()[:125].keys()),ply['age'].value_counts()[:125],color='grey')
# []

# %%
ply['nationality'].value_counts().keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands',
#        ...
#        'Mauritius', 'Chinese Taipei', 'Hong Kong', 'Chad', 'Jordan', 'Liberia',
#        'São Tomé & Príncipe', 'Puerto Rico', 'Bahrain', 'Indonesia'],
#       dtype='object', length=162)

# %%
plyy=ply[['age','short_name','wage_eur']]
plyy.head()
# Out:
#    age         short_name  wage_eur
# 0   32           L. Messi    565000
# 1   34  Cristiano Ronaldo    405000
# 2   27          Neymar Jr    290000
# 3   26           J. Oblak    125000
# 4   28          E. Hazard    470000

# %%
plyy.sort_values(by=['age'],ascending=True)
# Out:
#        age    short_name  wage_eur
# 18171   16   J. Starbuck      1000
# 4764    16     A. Hložek      1000
# 18243   16  E. Sartorius      1000
# 17827   16      D. Burns      1000
# 17614   16   D. Obbekjær      1000
# ...    ...           ...       ...
# 200     41     G. Buffon     58000
# 10665   41      F. Kippe      1000
# 3706    41  C. Lucchetti      5000
# 11832   42      C. Muñoz      1000
# 13003   42  H. Sulaimani      5000
#
# [18278 rows x 3 columns]

# %%
plyy.sort_values(by=['wage_eur'],ascending=False)
# Out:
#        age         short_name  wage_eur
# 0       32           L. Messi    565000
# 4       28          E. Hazard    470000
# 1       34  Cristiano Ronaldo    405000
# 5       28       K. De Bruyne    370000
# 22      28       A. Griezmann    370000
# ...    ...                ...       ...
# 565     31       J. Serendero         0
# 1868    29          M. Mevlja         0
# 14723   19       R. Fernández         0
# 16356   37          H. Ivanov         0
# 3053    32      F. Kudryashov         0
#
# [18278 rows x 3 columns]

# %%
plt.figure(figsize=(8,5))
plt.bar(list(plyy['short_name'])[0:5],list(plyy['wage_eur'])[0:5],color=['blue','purple','green','red','pink'])
plt.show()

# %%
ply['nationality']=='India'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
ind=ply[ply['nationality']=='India']

# %%
ind.head(5)
# Out:
#        sofifa_id                                         player_url  \
# 12155     251742  https://sofifa.com/player/251742/gajodara-chat...
# 13102     251723  https://sofifa.com/player/251723/prakul-bhatt/...
# 13103     251728  https://sofifa.com/player/251728/bhadrashree-r...
# 13970     251722  https://sofifa.com/player/251722/abhimoda-chak...
# 13971     251727  https://sofifa.com/player/251727/hantidev-bhan...
#
#            short_name             long_name  age         dob  height_cm  \
# 12155   G. Chatterjee   Gajodara Chatterjee   33  1985-07-04        195
# 13102        P. Bhatt          Prakul Bhatt   34  1985-04-07        182
# 13103          B. Raj       Bhadrashree Raj   31  1988-03-25        175
# 13970  A. Chakraborty  Abhimoda Chakraborty   33  1985-10-27        189
# 13971     H. Bhandari     Hantidev Bhandari   30  1989-06-22        178
#
#        weight_kg nationality   club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
ply['long_name']=='Sunil Chhetri'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: long_name, Length: 18278, dtype: bool

# %%
ply[ply['long_name']=='Bhaichung Bhutia']
# Out:
# C:\Users\jayma\AppData\Local\Temp\ipykernel_35344\1334282875.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ind[ply['long_name']=='Bhaichung Bhutia']
# Empty DataFrame
# ...

# %%
ind.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 12155     251742  https://sofifa.com/player/251742/gajodara-chat...
# 13970     251722  https://sofifa.com/player/251722/abhimoda-chak...
# 16303     251733  https://sofifa.com/player/251733/palkesh-nagar...
# 15205     251747  https://sofifa.com/player/251747/anuvinda-khur...
# 15866     251726  https://sofifa.com/player/251726/diasha-sundar...
#
#            short_name             long_name  age         dob  height_cm  \
# 12155   G. Chatterjee   Gajodara Chatterjee   33  1985-07-04        195
# 13970  A. Chakraborty  Abhimoda Chakraborty   33  1985-10-27        189
# 16303    P. Nagarajan     Palkesh Nagarajan   29  1989-10-12        189
# 15205      A. Khurana      Anuvinda Khurana   26  1993-04-21        186
# 15866     D. Sundaram       Diasha Sundaram   30  1989-04-28        186
#
#        weight_kg nationality   club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
ply.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 10693     156321  https://sofifa.com/player/156321/adebayo-akinf...
# 9572      179685  https://sofifa.com/player/179685/chris-seitz/2...
# 15064     237399  https://sofifa.com/player/237399/evan-louro/20...
# 7439      195357  https://sofifa.com/player/195357/fabien-farnol...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
#
#          short_name          long_name  age         dob  height_cm  weight_kg  \
# 10693  A. Akinfenwa  Adebayo Akinfenwa   37  1982-05-10        178        110
# 9572       C. Seitz        Chris Seitz   32  1987-03-12        191        107
# 15064      E. Louro         Evan Louro   23  1996-01-19        191        104
# 7439    F. Farnolle    Fabien Farnolle   34  1985-02-05        196        104
# 13576  L. Watkowiak    Lukas Watkowiak   23  1996-03-06        197        103
#
#          nationality                club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
ind.sort_values(by=['sofifa_id'],ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 16714     251750  https://sofifa.com/player/251750/dhwanil-singh...
# 16300     251749  https://sofifa.com/player/251749/omesh-patla/2...
# 15868     251748  https://sofifa.com/player/251748/dinkerrai-baj...
# 15205     251747  https://sofifa.com/player/251747/anuvinda-khur...
# 15867     251746  https://sofifa.com/player/251746/randhir-jayar...
# 16354     251745  https://sofifa.com/player/251745/chapal-palan/...
# 15204     251743  https://sofifa.com/player/251743/adit-ginti/20...
# 12155     251742  https://sofifa.com/player/251742/gajodara-chat...
# 15809     251739  https://sofifa.com/player/251739/vihaan-boral/...
# 13972     251736  https://sofifa.com/player/251736/anvit-swamina...
# 16353     251735  https://sofifa.com/player/251735/amanpreet-var...
# 16303     251733  https://sofifa.com/player/251733/palkesh-nagar...
# 15324     251732  https://sofifa.com/player/251732/remil-nadkarn...
# ...

# %%
pp=ply[['wage_eur','short_name','sofifa_id']].sort_values(by=['wage_eur'],ascending=False).head(11)
pp
# Out:
#     wage_eur         short_name  sofifa_id
# 0     565000           L. Messi     158023
# 4     470000          E. Hazard     183277
# 1     405000  Cristiano Ronaldo      20801
# 5     370000       K. De Bruyne     192985
# 22    370000       A. Griezmann     194765
# 19    355000          L. Suárez     176580
# 8     340000          L. Modrić     177003
# 36    330000           T. Kroos     182521
# 17    300000          S. Agüero     153079
# 21    300000    Sergio Busquets     189511
# 18    300000       Sergio Ramos     155862

# %%
ply[['short_name','shooting','sofifa_id']].sort_values(by=['shooting'],ascending=False).head(9)
# Out:
#             short_name  shooting  sofifa_id
# 1    Cristiano Ronaldo      93.0      20801
# 0             L. Messi      92.0     158023
# 12             H. Kane      91.0     202126
# 17           S. Agüero      90.0     153079
# 205    F. Quagliarella      89.0     159261
# 19           L. Suárez      89.0     176580
# 96      Z. Ibrahimović      88.0      41236
# 37             M. Reus      88.0     188350
# 100            G. Bale      87.0     173731

# %%
real=ply[ply['club']=='Real Madrid']
real.head(3)
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
#
#    nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# 4      Belgium  Real Madrid  ...  66+3  63+3  63+3  63+3  66+3  61+3  49+3
# 8      Croatia  Real Madrid  ...  81+3  81+3  81+3  81+3  81+3  79+3  72+3
# 18       Spain  Real Madrid  ...  80+3  84+3  84+3  84+3  80+3  82+3  87+3
#
#       cb   rcb    rb
# 4   49+3  49+3  61+3
# 8   72+3  72+3  79+3
# 18  87+3  87+3  82+3
# ...

# %%
realm=ply[['short_name','club','player_url']].head(3)

# %%
realm
# Out:
#           short_name                 club  \
# 0           L. Messi         FC Barcelona
# 1  Cristiano Ronaldo             Juventus
# 2          Neymar Jr  Paris Saint-Germain
#
#                                           player_url
# 0  https://sofifa.com/player/158023/lionel-messi/...
# 1  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2  https://sofifa.com/player/190871/neymar-da-sil...

# %%
ply['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
passes=real[['short_name','wage_eur','club']]
passes.head(6)
# Out:
#       short_name  wage_eur         club
# 4      E. Hazard    470000  Real Madrid
# 8      L. Modrić    340000  Real Madrid
# 18  Sergio Ramos    300000  Real Madrid
# 28   T. Courtois    235000  Real Madrid
# 36      T. Kroos    330000  Real Madrid
# 42      Casemiro    240000  Real Madrid

# %%
passes.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#       short_name  wage_eur         club
# 4      E. Hazard    470000  Real Madrid
# 8      L. Modrić    340000  Real Madrid
# 36      T. Kroos    330000  Real Madrid
# 18  Sergio Ramos    300000  Real Madrid
# 46    K. Benzema    285000  Real Madrid
